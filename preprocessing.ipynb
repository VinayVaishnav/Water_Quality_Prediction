# %% [markdown]
# ## Importing the modules & libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
import random

import warnings
warnings.filterwarnings('ignore')

# %%
import sklearn
from sklearnex import patch_sklearn
patch_sklearn()
from sklearn.preprocessing import LabelEncoder
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %% [markdown]
# ## Preprocessing the dataset

# %%
df = pd.read_csv('water.csv')

# %%
df = df.drop(['Index'], axis=1)

# %%
df = df.fillna(np.nan)

# %%
drop_column_rows = ['Iron', 'Nitrate', 'Lead', 'Color', 'Turbidity', 'Odor', 'Chlorine', 'Total Dissolved Solids', 
'Source', 'Air Temperature', 'Month', 'Day', 'Time of Day']

# %%
for each in drop_column_rows:
    df = df[pd.notna(df[each])]

# %%
df['pH'].fillna(np.mean(df['pH']), inplace=True)

# %%
fillna_cols = ['pH', 'Chloride', 'Zinc', 'Fluoride', 'Copper', 'Sulfate', 'Conductivity', 'Manganese', 'Water Temperature']

# %%
for each in fillna_cols:
    df[each].fillna(np.mean(df[each]), inplace=True)

# %%
sourceslist = list(np.unique(df.Source))
sourceslist.sort()

# %%
sourceslist
# Out:
# ['Aquifer', 'Ground', 'Lake', 'Reservoir', 'River', 'Spring', 'Stream', 'Well']

# %%
replacesourceslist = [each for each in range(len(sourceslist))]
replacesourceslist
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]

# %%
colors = {
    'Colorless': 0,
    'Near Colorless': 1,
    'Faint Yellow': 2,
    'Light Yellow': 3,
    'Yellow': 4,
}

# %%
colorslist = []
replacecolorslist = []

for each in colors:
    colorslist.append(each)
    replacecolorslist.append(colors[each])
    
print(colorslist)
print(replacecolorslist)
# Out:
# ['Colorless', 'Near Colorless', 'Faint Yellow', 'Light Yellow', 'Yellow']
# [0, 1, 2, 3, 4]

# %%
df['Color'].replace(colorslist, replacecolorslist, inplace=True)

# %%
df['Source'].replace(sourceslist, replacesourceslist, inplace=True)

# %%
df = df.drop(['Month', 'Day', 'Time of Day'], axis=1)

# %%
df
# Out:
#                pH      Iron   Nitrate    Chloride           Lead      Zinc  \
# 1        6.917863  0.000081  3.734167  227.029851   7.849262e-94  1.245317
# 2        5.443762  0.020106  3.816994  230.995630   5.286616e-76  0.528280
# 4        8.091909  0.002167  9.925788  186.540872  4.171069e-132  3.807511
# 5        7.445251  0.000006  1.702584  162.828458   6.102202e-23  3.742464
# 6        8.132455  0.055262  4.288010   94.993978   2.919909e-52  1.770221
# ...           ...       ...       ...         ...            ...       ...
# 5956834  7.336513  0.000799  3.807672   89.956213   4.258296e-34  3.027267
# 5956835  8.161283  0.000015  6.552120  309.134213   3.368973e-44  2.127818
# 5956837  8.418457  0.000095  8.427576  256.570863   4.751543e-26  4.967504
# 5956838  7.950573  0.215729  4.677850  292.727780   4.679421e-12  1.842063
# 5956841  7.539523  0.022760  4.902591  106.256430   1.399449e-10  1.069694
#
#          Color  Turbidity  Fluoride    Copper      Odor     Sulfate  \
# 1            2   0.019007  0.622874  0.437835  1.686049  144.010981
# 2            3   0.319956  0.423423  0.431588  3.414619  275.702107
# 4            3   0.004867  0.222912  0.616574  0.795310  175.275175
# 5            1   0.504791  0.054562  0.851326  1.270483   40.853403
# 6            3   0.021703  1.111893  0.247116  0.426404  146.073521
# ...        ...        ...       ...       ...       ...         ...
# 5956834      2   0.010288  0.745372  0.186357  2.585437  145.362834
# 5956835      3   0.201469  3.419696  3.170538  1.931928   43.043399
# 5956837      2   3.824532  0.541850  0.284838  0.299860  371.261098
# 5956838      1   1.181166  2.747241  1.367155  3.749374  198.070171
# 5956841      3   0.371766  0.995846  1.665171  2.530943   79.593261
#
#          Conductivity  Chlorine     Manganese  Total Dissolved Solids  Source  \
# 1          432.844908  3.292038  8.024076e-07              284.641984       2
# 2          990.201209  3.560224  7.007989e-02              570.054094       4
# 4          385.025855  3.177849  3.296139e-03              168.075545       5
# 5          273.359662  3.957842  2.863952e-04              365.639045       6
# 6          265.530096  1.706755  3.083768e-02              266.079565       0
# ...               ...       ...           ...                     ...     ...
# 5956834    533.374053  2.553024  1.428103e-02                1.634232       2
# 5956835    366.349236  3.180415  7.086033e-04               19.767936       6
# 5956837    339.150786  2.630130  9.608234e-03              545.990529       7
# 5956838    521.505506  3.555576  1.875424e-11              514.136530       1
# 5956841    282.713146  6.033203  2.838596e-01              118.556879       0
#
#          Water Temperature  Air Temperature  Target
# 1                15.348981        71.220586       0
# 2                11.643467        44.891330       0
# 4                15.249416        69.336671       0
# 5                13.966842        45.444798       0
# 6                27.920380        68.104498       0
# ...                    ...              ...     ...
# 5956834          18.610969        82.445237       1
# 5956835          26.160882        45.900772       1
# 5956837          21.436974        70.493951       1
# 5956838          19.064632        67.052475       1
# 5956841           6.594036        51.751181       1
#
# [5120110 rows x 20 columns]

# %%
df = df.reset_index()

# %%
df=df.drop(columns=["index"],axis=1)

# %%
df
# Out:
#                pH      Iron   Nitrate    Chloride           Lead      Zinc  \
# 0        6.917863  0.000081  3.734167  227.029851   7.849262e-94  1.245317
# 1        5.443762  0.020106  3.816994  230.995630   5.286616e-76  0.528280
# 2        8.091909  0.002167  9.925788  186.540872  4.171069e-132  3.807511
# 3        7.445251  0.000006  1.702584  162.828458   6.102202e-23  3.742464
# 4        8.132455  0.055262  4.288010   94.993978   2.919909e-52  1.770221
# ...           ...       ...       ...         ...            ...       ...
# 5120105  7.336513  0.000799  3.807672   89.956213   4.258296e-34  3.027267
# 5120106  8.161283  0.000015  6.552120  309.134213   3.368973e-44  2.127818
# 5120107  8.418457  0.000095  8.427576  256.570863   4.751543e-26  4.967504
# 5120108  7.950573  0.215729  4.677850  292.727780   4.679421e-12  1.842063
# 5120109  7.539523  0.022760  4.902591  106.256430   1.399449e-10  1.069694
#
#          Color  Turbidity  Fluoride    Copper      Odor     Sulfate  \
# 0            2   0.019007  0.622874  0.437835  1.686049  144.010981
# 1            3   0.319956  0.423423  0.431588  3.414619  275.702107
# 2            3   0.004867  0.222912  0.616574  0.795310  175.275175
# 3            1   0.504791  0.054562  0.851326  1.270483   40.853403
# 4            3   0.021703  1.111893  0.247116  0.426404  146.073521
# ...        ...        ...       ...       ...       ...         ...
# 5120105      2   0.010288  0.745372  0.186357  2.585437  145.362834
# 5120106      3   0.201469  3.419696  3.170538  1.931928   43.043399
# 5120107      2   3.824532  0.541850  0.284838  0.299860  371.261098
# 5120108      1   1.181166  2.747241  1.367155  3.749374  198.070171
# 5120109      3   0.371766  0.995846  1.665171  2.530943   79.593261
#
#          Conductivity  Chlorine     Manganese  Total Dissolved Solids  Source  \
# 0          432.844908  3.292038  8.024076e-07              284.641984       2
# 1          990.201209  3.560224  7.007989e-02              570.054094       4
# 2          385.025855  3.177849  3.296139e-03              168.075545       5
# 3          273.359662  3.957842  2.863952e-04              365.639045       6
# 4          265.530096  1.706755  3.083768e-02              266.079565       0
# ...               ...       ...           ...                     ...     ...
# 5120105    533.374053  2.553024  1.428103e-02                1.634232       2
# 5120106    366.349236  3.180415  7.086033e-04               19.767936       6
# 5120107    339.150786  2.630130  9.608234e-03              545.990529       7
# 5120108    521.505506  3.555576  1.875424e-11              514.136530       1
# 5120109    282.713146  6.033203  2.838596e-01              118.556879       0
#
#          Water Temperature  Air Temperature  Target
# 0                15.348981        71.220586       0
# 1                11.643467        44.891330       0
# 2                15.249416        69.336671       0
# 3                13.966842        45.444798       0
# 4                27.920380        68.104498       0
# ...                    ...              ...     ...
# 5120105          18.610969        82.445237       1
# 5120106          26.160882        45.900772       1
# 5120107          21.436974        70.493951       1
# 5120108          19.064632        67.052475       1
# 5120109           6.594036        51.751181       1
#
# [5120110 rows x 20 columns]

# %% [markdown]
# ## Saving the preprocessed dataset

# %%
df.to_csv('preprocessed_water.csv', index=False)
